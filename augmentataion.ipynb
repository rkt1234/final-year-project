# %%
import cv2
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
import os
import glob
import random

# %%
for folder in range (1,164):
        count = 0
        for img in glob.glob(rf"Person_{folder}\*.JPG"):
            cv_img = cv2.imread(img)
            cv_img = cv2.cvtColor(cv_img, cv2.COLOR_BGR2RGB)
            cv_img = cv2.resize(cv_img, (256, 256))
            type(cv_img)
            datagen = ImageDataGenerator(
                brightness_range=(0.8, 1.2),
                horizontal_flip=True,
                rotation_range=random.randint(1,30),
                shear_range=(random.randint(1,2))/10,
                zoom_range=(random.randint(1, 2))/10
            )
            print(cv_img.shape)
            input_batch = cv_img.reshape(1, 256, 256, 3)
            print(cv_img.shape[0])

            i = 0
            for output in datagen.flow(input_batch, batch_size=1, save_to_dir=rf"C:\Users\RAVIKANT TIWARI\Desktop\augmentation\Person_{folder}", save_format='JPG'):
                i = i+1
                if i == 10:
                    break
# Out:
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# (256, 256, 3)
# 256
# ...
